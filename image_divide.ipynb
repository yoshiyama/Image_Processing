# %%
# find current working directory
import glob
import os
#print current working directory
path = os.getcwd()
print("The current working directory is = \n",path)
# Out:
# The current working directory is =
#  C:\GitHub

# %%
# if necesary
#change to other directory
# dir='C:\GitHub\pix2pix-tensorflow-master_landslide\datasets\\facades\\train'
# dir='Image_Processing/'
dir=r'C:\GitHub\Image_Processing\out'
os.chdir(dir)
path = os.getcwd()
print("The current working directory is = \n",path)
# Out:
# The current working directory is =
#  C:\GitHub\Image_Processing\out

# %%
path = os.getcwd()
print(path)

# %%
# import
from os import listdir

files = listdir(path)
print(files)

# %%
# load images

# %%
# image processing

# %%
# save images
